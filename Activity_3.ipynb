# %%
# %run common.ipy

# %%
pd.set_option('max_rows', None)
pd.set_option('max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
# %ls datasets/
# Out:
# Book3.csv                  data.csv
# Canada.xlsx                headbrain.csv
# Cartwheeldata.csv          mic2.xlsx
# adult.csv                  movies.csv
# airline_data.csv           nhanes_2015_2016.csv
# antropometria-dataset.csv  pokemon.csv
# antropometria00.csv        reg_data.csv
# census.csv                 sample_pivot.csv
# coches.csv                 tips.csv
# cwurData.csv               weight-height.csv

# %%
df=pd.read_csv('datasets/antropometria-dataset.csv')
df.head(4)
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
#
#   est_urb est_marg       pondef  est_var
# 0       3        1  3470.002176      215
# 1       1        1   417.946672      101
# 2       3        1   472.980811       15
# 3       3        2  1832.581391       94
#
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
pivot1=pd.pivot_table(df,index=['desc_ent'],
               aggfunc = 'mean',
               values=['peso']
              )
pivot1
# Out:
#                                       peso
# desc_ent
# AGUASCALIENTES                   66.357786
# BAJA CALIFORNIA                  68.467270
# BAJA CALIFORNIA SUR              71.809198
# CAMPECHE                         65.418475
# CHIAPAS                          57.613775
# CHIHUAHUA                        66.656005
# COAHUILA DE ZARAGOZA             68.154142
# COLIMA                           68.743648
# DISTRITO FEDERAL                 65.119273
# DURANGO                          66.354922
# GUANAJUATO                       63.936390
# GUERRERO                         60.466315
# HIDALGO                          59.995917
# JALISCO                          66.697270
# MEXICO                           60.680850
# MICHOACAN DE OCAMPO              64.900000
# MORELOS                          63.541295
# NAYARIT                          66.541827
# NUEVO LEON                       67.239853
# OAXACA                           58.800067
# ...

# %%
pivot1=pd.pivot_table(df,index=['desc_ent'],
               aggfunc = 'median',
               values=['peso']
              )
pivot1
# Out:
#                                     peso
# desc_ent
# AGUASCALIENTES                   66.6000
# BAJA CALIFORNIA                  67.9500
# BAJA CALIFORNIA SUR              71.2500
# CAMPECHE                         64.3500
# CHIAPAS                          57.2000
# CHIHUAHUA                        66.3000
# COAHUILA DE ZARAGOZA             67.7000
# COLIMA                           68.9000
# DISTRITO FEDERAL                 64.0250
# DURANGO                          65.7000
# GUANAJUATO                       62.0625
# GUERRERO                         57.9500
# HIDALGO                          59.7000
# JALISCO                          64.2000
# MEXICO                           59.5500
# MICHOACAN DE OCAMPO              65.8000
# MORELOS                          62.5750
# NAYARIT                          66.6250
# NUEVO LEON                       66.7000
# OAXACA                           57.6000
# PUEBLA                           60.3500
# QUERETARO                        62.4000
# ...

# %%
pivot2=pd.pivot_table(df,index=['desc_ent'],
               aggfunc = 'mean',
               values=['peso'],
               columns=['sexo'],
               sort=True
              )

pivot2
# Out:
#                                       peso
# sexo                                     1          2
# desc_ent
# AGUASCALIENTES                   69.985381  63.254292
# BAJA CALIFORNIA                  71.391818  65.893667
# BAJA CALIFORNIA SUR              75.561015  68.168959
# CAMPECHE                         68.622637  62.920493
# CHIAPAS                          58.365222  57.096111
# CHIHUAHUA                        68.892642  64.815295
# COAHUILA DE ZARAGOZA             68.873094  67.467348
# COLIMA                           70.998878  66.978393
# DISTRITO FEDERAL                 69.460661  61.654128
# DURANGO                          68.846451  64.400031
# GUANAJUATO                       65.008000  63.100995
# GUERRERO                         62.611437  58.899850
# HIDALGO                          61.747958  58.972554
# JALISCO                          67.076482  66.418111
# MEXICO                           63.140314  58.887882
# ...

# %%
pivot2.iloc[:,0].min()
# Out:
# 58.36522177419355

# %%
df2=pd.read_csv('datasets/adult.csv')
df2.head(4)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
#
#         marital-status          occupation    relationship    race    sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country the label
# 0          2174             0              40   United-States     <=50K
# 1             0             0              13   United-States     <=50K
# ...

# %%
df2.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'the label'],
#       dtype='object')

# %%
df2['marital-status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
#  test_category_male           2
#  test_category_female         1
# Name: marital-status, dtype: int64

# %%
pivot2=pd.pivot_table(df2,index=['marital-status','education'],
               aggfunc = 'mean',
                values=['age']
              )
pivot2
# Out:
#                                             age
# marital-status         education
#  Divorced               10th          44.133333
#                         11th          41.230769
#                         12th          41.333333
#                         1st-4th       62.700000
#                         5th-6th       53.700000
#                         7th-8th       49.452055
#                         9th           46.281250
#                         Assoc-acdm    41.064039
#                         Assoc-voc     40.653846
#                         Bachelors     44.243590
#                         Doctorate     49.303030
#                         HS-grad       42.363918
#                         Masters       47.278970
#                         Preschool     36.000000
#                         Prof-school   44.127273
#                         Some-college  42.327409
#  Married-AF-spouse      Assoc-acdm    31.500000
#                         Assoc-voc     29.000000
# ...

# %%
df2.groupby(['marital-status']).size()
# Out:
# marital-status
#  Divorced                  4443
#  Married-AF-spouse           23
#  Married-civ-spouse       14976
#  Married-spouse-absent      418
#  Never-married            10683
#  Separated                 1025
#  Widowed                    993
#  test_category_female         1
#  test_category_male           2
# dtype: int64

# %%
(df2.groupby(['marital-status']).size()/df2.shape[0])*100
# Out:
# marital-status
#  Divorced                 13.643901
#  Married-AF-spouse         0.070630
#  Married-civ-spouse       45.989436
#  Married-spouse-absent     1.283626
#  Never-married            32.806166
#  Separated                 3.147648
#  Widowed                   3.049380
#  test_category_female      0.003071
#  test_category_male        0.006142
# dtype: float64

# %%
pivot2=pd.pivot_table(df2,index=['education','marital-status'],
               aggfunc = 'median',
                values=['age'],
                columns=['sex']
              )
pivot2
# Out:
#                                          age
# sex                                   Female  Male
# education     marital-status
#  10th          Divorced                 45.0  39.0
#                Married-civ-spouse       32.0  48.0
#                Married-spouse-absent    39.0  49.0
#                Never-married            18.0  20.0
#                Separated                34.0  38.0
#                Widowed                  60.0  57.0
#  11th          Divorced                 41.0  38.0
#                Married-civ-spouse       42.0  41.0
#                Married-spouse-absent    30.0  32.5
#                Never-married            18.0  18.0
#                Separated                35.5  34.5
#                Widowed                  56.0  60.0
#  12th          Divorced                 41.0  41.0
#                Married-civ-spouse       34.0  41.5
#                Married-spouse-absent    25.5  46.0
#                Never-married            18.0  20.5
# ...
